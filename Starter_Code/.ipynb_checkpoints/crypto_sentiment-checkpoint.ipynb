# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jyoun\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
print(api_key)
# Out:
# 54cc924eb9e34b2daf7e55042233eab1

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news_en = newsapi.get_everything(
    q="Bitcoin",
    language="en"
)

# Show the total number of news
bitcoin_news_en["totalResults"]
# Out:
# 8207

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
ethereum_news = newsapi.get_everything(
    q="Ethereum",
    language="en")

# Show the total number of news
ethereum_news["totalResults"]
# Out:
# 2250

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!


bitcoin_sentiments = []

for article in bitcoin_news_en["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-06-14  It's all about clean energy, it seems. \r\nElo...    0.6908
# 1  2021-07-05  Filed under:\r\nThe supply chain attack has re...   -0.5719
# 2  2021-07-05  image copyrightGetty Images\r\nThe gang behind...   -0.6124
# 3  2021-06-16  SAN SALVADOR, June 16 (Reuters) - El Salvador ...    0.1280
# 4  2021-06-23  LONDON, June 23 (Reuters) - El Salvador is det...    0.2023
#
#    positive  negative  neutral
# 0     0.169     0.000    0.831
# 1     0.111     0.184    0.705
# 2     0.000     0.143    0.857
# 3     0.043     0.000    0.957
# 4     0.105     0.057    0.838

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-06-17  TL;DR: The Cryptocurrency with Ethereum and So...    0.0000
# 1  2021-06-20  It wasn't long ago that your average person ha...   -0.2960
# 2  2021-07-02  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612
# 3  2021-07-05  Ether holders have "staked" more than $13 bill...    0.7717
# 4  2021-07-05  Ether is the cryptocurrency of the ethereum ne...    0.6249
#
#    positive  negative  neutral
# 0     0.000     0.000    1.000
# 1     0.000     0.061    0.939
# 2     0.110     0.041    0.849
# 3     0.194     0.000    0.806
# 4     0.150     0.000    0.850

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!

bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.038955   0.044050   0.044100   0.911800
# std     0.343282   0.056322   0.053606   0.077889
# min    -0.612400   0.000000   0.000000   0.705000
# 25%    -0.381800   0.000000   0.000000   0.853000
# 50%     0.000000   0.000000   0.028500   0.923000
# 75%     0.146575   0.089250   0.075500   0.967750
# max     0.690800   0.169000   0.184000   1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.075045   0.040500   0.022750   0.936750
# std     0.350432   0.058708   0.032751   0.055265
# min    -0.381800   0.000000   0.000000   0.806000
# 25%    -0.273200   0.000000   0.000000   0.920000
# 50%     0.000000   0.000000   0.000000   0.937000
# 75%     0.361200   0.074750   0.060000   1.000000
# max     0.771700   0.194000   0.080000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin had the highest mean positive score.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum have the highest compand score
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum had the highest positive score

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
print(stopwords.words('english'))
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Complete the tokenizer function
def tokenizer(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', article)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw.union(stop_words)]
    return output

# %%
# Compile the list of lists of tokens for each Bitcoin article
btc_word_tokenized = []
for text in bitcoin_df.text:
    # Create a list of tokenized words for each article    
    words = []
    words = words + tokenizer(text)
    # append all lists of tokenized words for each article to the btc_word_tokenized list of lists
    btc_word_tokenized.append(words)
print(btc_word_tokenized)
# Out:
# [['clean', 'energy', 'seemselon', 'musk', 'tesla', 'caused', 'ripple', 'cryptocurrency', 'market', 'past', 'month', 'first', 'announcing', 'tesla', 'bought', 'billion', 'worth', 'bitcoi', 'char'], ['filed', 'underthe', 'supply', 'chain', 'attack', 'ha', 'reached', 'thousand', 'organizationsillustration', 'alex', 'castro', 'vergethree', 'day', 'ransomware', 'attacker', 'started', 'holiday', 'weekend', 'comprom', 'char'], ['image', 'copyrightgetty', 'imagesthe', 'gang', 'behind', 'colossal', 'ransomware', 'attack', 'ha', 'demanded', 'paid', 'bitcoin', 'return', 'universal', 'decryptor', 'say', 'unlock', 'file', 'char'], ['san', 'salvador', 'june', 'reuters', 'el', 'salvador', 'replace', 'us', 'dollar', 'bitcoin', 'legal', 'tender', 'finance', 'minister', 'alejandro', 'zelaya', 'wednesday', 'central', 'american', 'nation', 'char'], ['london', 'june', 'reuters', 'el', 'salvador', 'determined', 'push', 'ahead', 'making', 'bitcoin', 'legal', 'tender', 'process', 'bring', 'small', 'risk', 'prove', 'leap', 'forward', 'humanity', 'country', 'pr', 'char'], ['london', 'june', 'reuters', 'el', 'salvador', 'determined', 'push', 'ahead', 'making', 'bitcoin', 'legal', 'tender', 'process', 'bring', 'small', 'risk', 'prove', 'leap', 'forward', 'humanity', 'country', 'char'], ['reuters', 'staffsan', 'salvador', 'reuters', 'el', 'salvador', 'replace', 'us', 'dollar', 'bitcoin', 'legal', 'tender', 'finance', 'minister', 'alejandro', 'zelaya', 'wednesday', 'central', 'american', 'char'], ['hello', 'welcome', 'back', 'toequity', 'techcrunchs', 'venture', 'capitalfocused', 'podcast', 'unpack', 'number', 'behind', 'headlinesthis', 'equity', 'monday', 'morning', 'coffee', 'chat', 'ab', 'char'], ['story', 'originally', 'appeared', 'marketbeatwhen', 'meme', 'coin', 'surged', 'earlier', 'year', 'remember', 'dogecoin', 'mania', 'mightve', 'easy', 'dump', 'everything', 'owned', 'stock', 'bond', 'gold', 'crypto', 'char'], ['reuters', 'staffadds', 'context', 'backgroundjune', 'reuters', 'bitcoin', 'surged', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryp', 'char'], ['representation', 'virtual', 'currency', 'bitcoin', 'seen', 'front', 'stock', 'graph', 'illustration', 'taken', 'march', 'reutersdado', 'ruvicillustrationlondon', 'june', 'reuters', 'youre', 'bitcoi', 'char'], ['tokyo', 'june', 'reuters', 'cryptocurrencies', 'tumbled', 'monday', 'chinas', 'crackdown', 'bitcoin', 'mining', 'expanded', 'province', 'sichuan', 'read', 'bitcoin', 'fell', 'low', 'first', 'char'], ['reuters', 'stafffile', 'photo', 'representations', 'bitcoin', 'cryptocurrency', 'seen', 'picture', 'illustration', 'taken', 'june', 'reutersedgar', 'suillustrationreuters', 'bitcoin', 'dropped', 'char'], ['bitcoin', 'dropped', 'gmt', 'saturday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'high', 'char'], ['june', 'reuters', 'bitcoin', 'dipped', 'gmt', 'monday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'dipped', 'gmt', 'monday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['representation', 'virtual', 'cryptocurrency', 'bitcoin', 'seen', 'picture', 'illustration', 'taken', 'june', 'reutersedgar', 'suillustrationjune', 'reuters', 'bitcoin', 'dropped', 'char'], ['posted', 'bitcoin', 'tumbled', 'monday', 'news', 'fresh', 'crackdown', 'cryptocurrencys', 'miner', 'china'], ['reuters', 'stafffile', 'photo', 'representations', 'bitcoin', 'cryptocurrency', 'seen', 'illustration', 'picture', 'taken', 'june', 'reutersedgar', 'suillustrationfile', 'photoreuters', 'bitcoin', 'ro', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'dropped', 'friday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char']]

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
bitcoin_df["tokens"]=btc_word_tokenized
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-06-14  It's all about clean energy, it seems. \r\nElo...    0.6908
# 1  2021-07-05  Filed under:\r\nThe supply chain attack has re...   -0.5719
# 2  2021-07-05  image copyrightGetty Images\r\nThe gang behind...   -0.6124
# 3  2021-06-16  SAN SALVADOR, June 16 (Reuters) - El Salvador ...    0.1280
# 4  2021-06-23  LONDON, June 23 (Reuters) - El Salvador is det...    0.2023
#
#    positive  negative  neutral  \
# 0     0.169     0.000    0.831
# 1     0.111     0.184    0.705
# 2     0.000     0.143    0.857
# 3     0.043     0.000    0.957
# 4     0.105     0.057    0.838
#
#                                               tokens
# 0  [clean, energy, seemselon, musk, tesla, caused...
# 1  [filed, underthe, supply, chain, attack, ha, r...
# 2  [image, copyrightgetty, imagesthe, gang, behin...
# 3  [san, salvador, june, reuters, el, salvador, r...
# 4  [london, june, reuters, el, salvador, determin...

# %%
# Compile the list of lists of tokens for each Ethereum article
eth_word_tokenized = []
for text in ethereum_df.text:
   # Create a list of tokenized words for each article 
    words = []
    words = words + tokenizer(text)
    # append all lists of tokenized words for each article to the eth_word_tokenized list of lists
    eth_word_tokenized.append(words)
print(eth_word_tokenized)
# Out:
# [['tldr', 'cryptocurrency', 'ethereum', 'solidity', 'blockchain', 'developer', 'bundle', 'sale', 'june', 'saving', 'list', 'priceis', 'everyone', 'know', 'investing', 'cryptocurrency', 'char'], ['wasnt', 'long', 'ago', 'average', 'person', 'clue', 'nft', 'wa', 'nowadays', 'theyre', 'making', 'headline', 'selling', 'hundred', 'thousand', 'buck', 'predictably', 'folk', 'learning', 'nfts', 'char'], ['bitcoin', 'ethereumyuriko', 'nakaoether', 'overtook', 'bitcoin', 'number', 'active', 'address', 'network', 'friday', 'sign', 'demand', 'faltering', 'world', 'biggest', 'cryptocurrency', 'co', 'char'], ['ether', 'holder', 'staked', 'billion', 'worth', 'cryptocurrency', 'ethereum', 'network', 'excitement', 'build', 'around', 'overhaul', 'system', 'potential', 'growth', 'staki', 'char'], ['ether', 'cryptocurrency', 'ethereum', 'networkphotothekgetty', 'imagesether', 'holder', 'staked', 'billion', 'worth', 'cryptocurrency', 'ethereum', 'network', 'excitement', 'char'], ['major', 'upgrade', 'ethereum', 'network', 'could', 'help', 'turn', 'crypto', 'staking', 'billion', 'business', 'according', 'analyst', 'jpmorganthe', 'staking', 'industry', 'user', 'earn', 'cryptocurrency', 'char'], ['sir', 'tim', 'bernerslee', 'credited', 'inventor', 'world', 'wide', 'web', 'selling', 'source', 'code', 'invention', 'nft', 'sothebys', 'auctionthe', 'nft', 'nonfungible', 'token', 'type', 'cryp', 'char'], ['two', 'ethereumbased', 'protocol', 'keep', 'network', 'nucypher', 'getting', 'upgradesinto', 'single', 'network', 'last', 'token', 'holder', 'project', 'voted'], ['youve', 'likely', 'seen', 'headline', 'surrounding', 'pretty', 'major', 'decline', 'nft', 'sale', 'market', 'recent', 'peak', 'report', 'indicating', 'much', 'percent', 'decline', 'recent', 'whi', 'char'], ['ambition', 'crypto', 'investor', 'swelled', 'even', 'faster', 'market', 'ha', 'recent', 'month', 'institutional', 'player', 'mountain', 'blockchain', 'data', 'try', 'make', 'sense', 'without', 'par', 'char'], ['bitcoin', 'dropped', 'gmt', 'saturday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'high', 'char'], ['tldr', 'cryptocurrency', 'ethereum', 'solidity', 'blockchain', 'developer', 'bundle', 'explains', 'entire', 'crypto', 'phenomenon', 'also', 'explores', 'creating', 'real', 'world', 'cryptocurrencyif', 'knowledge', 'char'], ['ina', 'fassbenderafp', 'via', 'getty', 'imagesinvestors', 'pulled', 'money', 'digital', 'asset', 'third', 'running', 'making', 'longest', 'series', 'consecutive', 'outflow', 'since', 'february', 'coinsh', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'surged', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['bitcoin', 'rose', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'year', 'low', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'rose', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'dropped', 'friday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['bitcoin', 'surged', 'gmt', 'sunday', 'adding', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'year', 'low', 'char'], ['reuters', 'staffjune', 'reuters', 'bitcoin', 'dipped', 'gmt', 'friday', 'losing', 'previous', 'closebitcoin', 'world', 'biggest', 'bestknown', 'cryptocurrency', 'char'], ['reuters', 'stafffile', 'photo', 'representations', 'bitcoin', 'cryptocurrency', 'seen', 'picture', 'illustration', 'taken', 'june', 'reutersedgar', 'suillustrationreuters', 'bitcoin', 'dropped', 'char']]

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
ethereum_df["tokens"]=eth_word_tokenized
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-06-17  TL;DR: The Cryptocurrency with Ethereum and So...    0.0000
# 1  2021-06-20  It wasn't long ago that your average person ha...   -0.2960
# 2  2021-07-02  Bitcoin and Ethereum\r\nYuriko Nakao\r\nEther ...    0.3612
# 3  2021-07-05  Ether holders have "staked" more than $13 bill...    0.7717
# 4  2021-07-05  Ether is the cryptocurrency of the ethereum ne...    0.6249
#
#    positive  negative  neutral  \
# 0     0.000     0.000    1.000
# 1     0.000     0.061    0.939
# 2     0.110     0.041    0.849
# 3     0.194     0.000    0.806
# 4     0.150     0.000    0.850
#
#                                               tokens
# 0  [tldr, cryptocurrency, ethereum, solidity, blo...
# 1  [wasnt, long, ago, average, person, clue, nft,...
# 2  [bitcoin, ethereumyuriko, nakaoether, overtook...
# 3  [ether, holder, staked, billion, worth, crypto...
# 4  [ether, cryptocurrency, ethereum, networkphoto...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
btc_flat_word_tokenized_list = [item for elem in btc_word_tokenized for item in elem]

# %%
btc_n_gram_counts = Counter(ngrams(btc_flat_word_tokenized_list, n=2))
print(dict(btc_n_gram_counts))
# Out:
# {('clean', 'energy'): 1, ('energy', 'seemselon'): 1, ('seemselon', 'musk'): 1, ('musk', 'tesla'): 1, ('tesla', 'caused'): 1, ('caused', 'ripple'): 1, ('ripple', 'cryptocurrency'): 1, ('cryptocurrency', 'market'): 1, ('market', 'past'): 1, ('past', 'month'): 1, ('month', 'first'): 1, ('first', 'announcing'): 1, ('announcing', 'tesla'): 1, ('tesla', 'bought'): 1, ('bought', 'billion'): 1, ('billion', 'worth'): 1, ('worth', 'bitcoi'): 1, ('bitcoi', 'char'): 2, ('char', 'filed'): 1, ('filed', 'underthe'): 1, ('underthe', 'supply'): 1, ('supply', 'chain'): 1, ('chain', 'attack'): 1, ('attack', 'ha'): 2, ('ha', 'reached'): 1, ('reached', 'thousand'): 1, ('thousand', 'organizationsillustration'): 1, ('organizationsillustration', 'alex'): 1, ('alex', 'castro'): 1, ('castro', 'vergethree'): 1, ('vergethree', 'day'): 1, ('day', 'ransomware'): 1, ('ransomware', 'attacker'): 1, ('attacker', 'started'): 1, ('started', 'holiday'): 1, ('holiday', 'weekend'): 1, ('weekend', 'comprom'): 1, ('comprom', 'char'): 1, ('char', 'image'): 1, ('image', 'copyrightgetty'): 1, ('copyrightgetty', 'imagesthe'): 1, ('imagesthe', 'gang'): 1, ('gang', 'behind'): 1, ('behind', 'colossal'): 1, ('colossal', 'ransomware'): 1, ('ransomware', 'attack'): 1, ('ha', 'demanded'): 1, ('demanded', 'paid'): 1, ('paid', 'bitcoin'): 1, ('bitcoin', 'return'): 1, ('return', 'universal'): 1, ('universal', 'decryptor'): 1, ('decryptor', 'say'): 1, ('say', 'unlock'): 1, ('unlock', 'file'): 1, ('file', 'char'): 1, ('char', 'san'): 1, ('san', 'salvador'): 1, ('salvador', 'june'): 1, ('june', 'reuters'): 6, ('reuters', 'el'): 4, ('el', 'salvador'): 4, ('salvador', 'replace'): 2, ('replace', 'us'): 2, ('us', 'dollar'): 2, ('dollar', 'bitcoin'): 2, ('bitcoin', 'legal'): 4, ('legal', 'tender'): 4, ('tender', 'finance'): 2, ('finance', 'minister'): 2, ('minister', 'alejandro'): 2, ('alejandro', 'zelaya'): 2, ('zelaya', 'wednesday'): 2, ('wednesday', 'central'): 2, ('central', 'american'): 2, ('american', 'nation'): 1, ('nation', 'char'): 1, ('char', 'london'): 2, ('london', 'june'): 2, ('salvador', 'determined'): 2, ('determined', 'push'): 2, ('push', 'ahead'): 2, ('ahead', 'making'): 2, ('making', 'bitcoin'): 2, ('tender', 'process'): 2, ('process', 'bring'): 2, ('bring', 'small'): 2, ('small', 'risk'): 2, ('risk', 'prove'): 2, ('prove', 'leap'): 2, ('leap', 'forward'): 2, ('forward', 'humanity'): 2, ('humanity', 'country'): 2, ('country', 'pr'): 1, ('pr', 'char'): 1, ('country', 'char'): 1, ('char', 'reuters'): 5, ('reuters', 'staffsan'): 1, ('staffsan', 'salvador'): 1, ('salvador', 'reuters'): 1, ('american', 'char'): 1, ('char', 'hello'): 1, ('hello', 'welcome'): 1, ('welcome', 'back'): 1, ('back', 'toequity'): 1, ('toequity', 'techcrunchs'): 1, ('techcrunchs', 'venture'): 1, ('venture', 'capitalfocused'): 1, ('capitalfocused', 'podcast'): 1, ('podcast', 'unpack'): 1, ('unpack', 'number'): 1, ('number', 'behind'): 1, ('behind', 'headlinesthis'): 1, ('headlinesthis', 'equity'): 1, ('equity', 'monday'): 1, ('monday', 'morning'): 1, ('morning', 'coffee'): 1, ('coffee', 'chat'): 1, ('chat', 'ab'): 1, ('ab', 'char'): 1, ('char', 'story'): 1, ('story', 'originally'): 1, ('originally', 'appeared'): 1, ('appeared', 'marketbeatwhen'): 1, ('marketbeatwhen', 'meme'): 1, ('meme', 'coin'): 1, ('coin', 'surged'): 1, ('surged', 'earlier'): 1, ('earlier', 'year'): 1, ('year', 'remember'): 1, ('remember', 'dogecoin'): 1, ('dogecoin', 'mania'): 1, ('mania', 'mightve'): 1, ('mightve', 'easy'): 1, ('easy', 'dump'): 1, ('dump', 'everything'): 1, ('everything', 'owned'): 1, ('owned', 'stock'): 1, ('stock', 'bond'): 1, ('bond', 'gold'): 1, ('gold', 'crypto'): 1, ('crypto', 'char'): 1, ('reuters', 'staffadds'): 1, ('staffadds', 'context'): 1, ('context', 'backgroundjune'): 1, ('backgroundjune', 'reuters'): 1, ('reuters', 'bitcoin'): 5, ('bitcoin', 'surged'): 1, ('surged', 'sunday'): 1, ('sunday', 'adding'): 1, ('adding', 'previous'): 1, ('previous', 'closebitcoin'): 5, ('closebitcoin', 'world'): 5, ('worl ...

# %%
# Generate the Ethereum N-grams where N=2
eth_flat_word_tokenized_list = [item for elem in eth_word_tokenized for item in elem]

# %%
eth_n_gram_counts = Counter(ngrams(eth_flat_word_tokenized_list, n=2))
print(dict(eth_n_gram_counts))
# Out:
# {('tldr', 'cryptocurrency'): 2, ('cryptocurrency', 'ethereum'): 5, ('ethereum', 'solidity'): 2, ('solidity', 'blockchain'): 2, ('blockchain', 'developer'): 2, ('developer', 'bundle'): 2, ('bundle', 'sale'): 1, ('sale', 'june'): 1, ('june', 'saving'): 1, ('saving', 'list'): 1, ('list', 'priceis'): 1, ('priceis', 'everyone'): 1, ('everyone', 'know'): 1, ('know', 'investing'): 1, ('investing', 'cryptocurrency'): 1, ('cryptocurrency', 'char'): 6, ('char', 'wasnt'): 1, ('wasnt', 'long'): 1, ('long', 'ago'): 1, ('ago', 'average'): 1, ('average', 'person'): 1, ('person', 'clue'): 1, ('clue', 'nft'): 1, ('nft', 'wa'): 1, ('wa', 'nowadays'): 1, ('nowadays', 'theyre'): 1, ('theyre', 'making'): 1, ('making', 'headline'): 1, ('headline', 'selling'): 1, ('selling', 'hundred'): 1, ('hundred', 'thousand'): 1, ('thousand', 'buck'): 1, ('buck', 'predictably'): 1, ('predictably', 'folk'): 1, ('folk', 'learning'): 1, ('learning', 'nfts'): 1, ('nfts', 'char'): 1, ('char', 'bitcoin'): 4, ('bitcoin', 'ethereumyuriko'): 1, ('ethereumyuriko', 'nakaoether'): 1, ('nakaoether', 'overtook'): 1, ('overtook', 'bitcoin'): 1, ('bitcoin', 'number'): 1, ('number', 'active'): 1, ('active', 'address'): 1, ('address', 'network'): 1, ('network', 'friday'): 1, ('friday', 'sign'): 1, ('sign', 'demand'): 1, ('demand', 'faltering'): 1, ('faltering', 'world'): 1, ('world', 'biggest'): 8, ('biggest', 'cryptocurrency'): 1, ('cryptocurrency', 'co'): 1, ('co', 'char'): 1, ('char', 'ether'): 2, ('ether', 'holder'): 1, ('holder', 'staked'): 2, ('staked', 'billion'): 2, ('billion', 'worth'): 2, ('worth', 'cryptocurrency'): 2, ('ethereum', 'network'): 3, ('network', 'excitement'): 2, ('excitement', 'build'): 1, ('build', 'around'): 1, ('around', 'overhaul'): 1, ('overhaul', 'system'): 1, ('system', 'potential'): 1, ('potential', 'growth'): 1, ('growth', 'staki'): 1, ('staki', 'char'): 1, ('ether', 'cryptocurrency'): 1, ('ethereum', 'networkphotothekgetty'): 1, ('networkphotothekgetty', 'imagesether'): 1, ('imagesether', 'holder'): 1, ('excitement', 'char'): 1, ('char', 'major'): 1, ('major', 'upgrade'): 1, ('upgrade', 'ethereum'): 1, ('network', 'could'): 1, ('could', 'help'): 1, ('help', 'turn'): 1, ('turn', 'crypto'): 1, ('crypto', 'staking'): 1, ('staking', 'billion'): 1, ('billion', 'business'): 1, ('business', 'according'): 1, ('according', 'analyst'): 1, ('analyst', 'jpmorganthe'): 1, ('jpmorganthe', 'staking'): 1, ('staking', 'industry'): 1, ('industry', 'user'): 1, ('user', 'earn'): 1, ('earn', 'cryptocurrency'): 1, ('char', 'sir'): 1, ('sir', 'tim'): 1, ('tim', 'bernerslee'): 1, ('bernerslee', 'credited'): 1, ('credited', 'inventor'): 1, ('inventor', 'world'): 1, ('world', 'wide'): 1, ('wide', 'web'): 1, ('web', 'selling'): 1, ('selling', 'source'): 1, ('source', 'code'): 1, ('code', 'invention'): 1, ('invention', 'nft'): 1, ('nft', 'sothebys'): 1, ('sothebys', 'auctionthe'): 1, ('auctionthe', 'nft'): 1, ('nft', 'nonfungible'): 1, ('nonfungible', 'token'): 1, ('token', 'type'): 1, ('type', 'cryp'): 1, ('cryp', 'char'): 1, ('char', 'two'): 1, ('two', 'ethereumbased'): 1, ('ethereumbased', 'protocol'): 1, ('protocol', 'keep'): 1, ('keep', 'network'): 1, ('network', 'nucypher'): 1, ('nucypher', 'getting'): 1, ('getting', 'upgradesinto'): 1, ('upgradesinto', 'single'): 1, ('single', 'network'): 1, ('network', 'last'): 1, ('last', 'token'): 1, ('token', 'holder'): 1, ('holder', 'project'): 1, ('project', 'voted'): 1, ('voted', 'youve'): 1, ('youve', 'likely'): 1, ('likely', 'seen'): 1, ('seen', 'headline'): 1, ('headline', 'surrounding'): 1, ('surrounding', 'pretty'): 1, ('pretty', 'major'): 1, ('major', 'decline'): 1, ('decline', 'nft'): 1, ('nft', 'sale'): 1, ('sale', 'market'): 1, ('market', 'recent'): 1, ('recent', 'peak'): 1, ('peak', 'report'): 1, ('report', 'indicating'): 1, ('indicating', 'much'): 1, ('much', 'percent'): 1, ('percent', 'decline'): 1, ('decline', 'recent'): 1, ('recent', 'whi'): 1, ('whi', 'char'): 1, ('char', 'ambition'): 1, ('ambition', 'crypto'): ...

# %%
# Function token_count generates the top 10 words for a given coin
def word_counter(coin_token_list): 
    top_10 = dict(Counter(coin_token_list).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
word_counter(btc_flat_word_tokenized_list)
# Out:
#              word  count
# 0         bitcoin     20
# 1            char     19
# 2         reuters     17
# 3            june      9
# 4  cryptocurrency      8
# 5        salvador      6
# 6          monday      5
# 7        previous      5
# 8    closebitcoin      5
# 9           world      5

# %%
# I blocked out this given code because I could figure it out. (I found a diff wa
#y to put top 10 in a DF about for bit and below for eth)
# Function token_count generates the top 10 words for a given coin
#def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
   # top_10 = dict(Counter(coin_token_list).most_common(10))
   # return Counter(tokens).most_common(N)
# Out:
#   File "<ipython-input-30-1dd06efd90c0>", line 5
#     """Returns the top N tokens from the frequency count"""
#     ^
# IndentationError: unexpected indent

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
word_counter(btc_flat_word_tokenized_list)
# Out:
#              word  count
# 0         bitcoin     20
# 1            char     19
# 2         reuters     17
# 3            june      9
# 4  cryptocurrency      8
# 5        salvador      6
# 6          monday      5
# 7        previous      5
# 8    closebitcoin      5
# 9           world      5

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
word_counter(eth_flat_word_tokenized_list)
# Out:
#              word  count
# 0            char     19
# 1  cryptocurrency     16
# 2         bitcoin     11
# 3           world     10
# 4         reuters      9
# 5         biggest      8
# 6        previous      7
# 7    closebitcoin      7
# 8       bestknown      7
# 9        ethereum      6

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Convert a list of tokens into a single string of tokens
btc_big_string = ' '.join([str(elem) for elem in btc_flat_word_tokenized_list ])
print(btc_big_string)
# Out:
# clean energy seemselon musk tesla caused ripple cryptocurrency market past month first announcing tesla bought billion worth bitcoi char filed underthe supply chain attack ha reached thousand organizationsillustration alex castro vergethree day ransomware attacker started holiday weekend comprom char image copyrightgetty imagesthe gang behind colossal ransomware attack ha demanded paid bitcoin return universal decryptor say unlock file char san salvador june reuters el salvador replace us dollar bitcoin legal tender finance minister alejandro zelaya wednesday central american nation char london june reuters el salvador determined push ahead making bitcoin legal tender process bring small risk prove leap forward humanity country pr char london june reuters el salvador determined push ahead making bitcoin legal tender process bring small risk prove leap forward humanity country char reuters staffsan salvador reuters el salvador replace us dollar bitcoin legal tender finance minister alejandro zelaya wednesday central american char hello welcome back toequity techcrunchs venture capitalfocused podcast unpack number behind headlinesthis equity monday morning coffee chat ab char story originally appeared marketbeatwhen meme coin surged earlier year remember dogecoin mania mightve easy dump everything owned stock bond gold crypto char reuters staffadds context backgroundjune reuters bitcoin surged sunday adding previous closebitcoin world biggest bestknown cryp char representation virtual currency bitcoin seen front stock graph illustration taken march reutersdado ruvicillustrationlondon june reuters youre bitcoi char tokyo june reuters cryptocurrencies tumbled monday chinas crackdown bitcoin mining expanded province sichuan read bitcoin fell low first char reuters stafffile photo representations bitcoin cryptocurrency seen picture illustration taken june reutersedgar suillustrationreuters bitcoin dropped char bitcoin dropped gmt saturday losing previous closebitcoin world biggest bestknown cryptocurrency high char june reuters bitcoin dipped gmt monday losing previous closebitcoin world biggest bestknown cryptocurrency char reuters staffjune reuters bitcoin dipped gmt monday losing previous closebitcoin world biggest bestknown cryptocurrency char representation virtual cryptocurrency bitcoin seen picture illustration taken june reutersedgar suillustrationjune reuters bitcoin dropped char posted bitcoin tumbled monday news fresh crackdown cryptocurrencys miner china reuters stafffile photo representations bitcoin cryptocurrency seen illustration picture taken june reutersedgar suillustrationfile photoreuters bitcoin ro char reuters staffjune reuters bitcoin dropped friday losing previous closebitcoin world biggest bestknown cryptocurrency char

# %%
import numpy as np

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!

btc_wc = WordCloud(background_color = 'white').generate(btc_big_string)
plt.axis("off")
plt.imshow(btc_wc)

# %%
# Convert a list of tokens into a single string of tokens
eth_big_string = ' '.join([str(elem) for elem in eth_flat_word_tokenized_list ])
print(eth_big_string)
# Out:
# tldr cryptocurrency ethereum solidity blockchain developer bundle sale june saving list priceis everyone know investing cryptocurrency char wasnt long ago average person clue nft wa nowadays theyre making headline selling hundred thousand buck predictably folk learning nfts char bitcoin ethereumyuriko nakaoether overtook bitcoin number active address network friday sign demand faltering world biggest cryptocurrency co char ether holder staked billion worth cryptocurrency ethereum network excitement build around overhaul system potential growth staki char ether cryptocurrency ethereum networkphotothekgetty imagesether holder staked billion worth cryptocurrency ethereum network excitement char major upgrade ethereum network could help turn crypto staking billion business according analyst jpmorganthe staking industry user earn cryptocurrency char sir tim bernerslee credited inventor world wide web selling source code invention nft sothebys auctionthe nft nonfungible token type cryp char two ethereumbased protocol keep network nucypher getting upgradesinto single network last token holder project voted youve likely seen headline surrounding pretty major decline nft sale market recent peak report indicating much percent decline recent whi char ambition crypto investor swelled even faster market ha recent month institutional player mountain blockchain data try make sense without par char bitcoin dropped gmt saturday losing previous closebitcoin world biggest bestknown cryptocurrency high char tldr cryptocurrency ethereum solidity blockchain developer bundle explains entire crypto phenomenon also explores creating real world cryptocurrencyif knowledge char ina fassbenderafp via getty imagesinvestors pulled money digital asset third running making longest series consecutive outflow since february coinsh char reuters staffjune reuters bitcoin surged gmt sunday adding previous closebitcoin world biggest bestknown cryptocurrency char bitcoin rose gmt sunday adding previous closebitcoin world biggest bestknown cryptocurrency year low char reuters staffjune reuters bitcoin rose gmt sunday adding previous closebitcoin world biggest bestknown cryptocurrency char reuters staffjune reuters bitcoin dropped friday losing previous closebitcoin world biggest bestknown cryptocurrency char bitcoin surged gmt sunday adding previous closebitcoin world biggest bestknown cryptocurrency year low char reuters staffjune reuters bitcoin dipped gmt friday losing previous closebitcoin world biggest bestknown cryptocurrency char reuters stafffile photo representations bitcoin cryptocurrency seen picture illustration taken june reutersedgar suillustrationreuters bitcoin dropped char

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
etc_wc = WordCloud(background_color = 'white').generate(eth_big_string)
plt.axis("off")
plt.imshow(etc_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_text = []
for text in bitcoin_df.text:
    btc_text.append(text)

# %%
# Convert a list of texts into a single string of texts   
btc_text_string = ' '.join([str(elem) for elem in btc_text])
print(btc_text_string)
# Out:
# It's all about clean energy, it seems.
# Elon Musk and Tesla caused ripples in the cryptocurrency market in the past few months, first by announcing that Tesla had bought $1.5 billion worth of bitcoi… [+2508 chars] Filed under:
# The supply chain attack has reached over a thousand organizations.
# Illustration by Alex Castro / The Verge
# Three days after ransomware attackers started the holiday weekend by comprom… [+3376 chars] image copyrightGetty Images
# The gang behind a "colossal" ransomware attack has demanded $70m (£50.5m) paid in Bitcoin in return for a "universal decryptor" that it says will unlock the files of all … [+4140 chars] SAN SALVADOR, June 16 (Reuters) - El Salvador will not replace the U.S. dollar with bitcoin as the legal tender, Finance Minister Alejandro Zelaya said on Wednesday, as the Central American nation so… [+1266 chars] LONDON, June 23 (Reuters) - El Salvador is determined to push ahead with making bitcoin legal tender, a process that will bring only small risks and prove a leap forward for humanity, the countrys Pr… [+2648 chars] LONDON, June 23 (Reuters) - El Salvador is determined to push ahead with making bitcoin legal tender, a process that will bring only small risks and prove a "leap forward for humanity", the country's… [+2764 chars] By Reuters Staff
# SAN SALVADOR (Reuters) - El Salvador will not replace the U.S. dollar with bitcoin as the legal tender, Finance Minister Alejandro Zelaya said on Wednesday, as the Central American … [+1110 chars] Hello and welcome back to Equity, TechCrunchs venture capital-focused podcast where we unpack the numbers behind the headlines.
# This is Equity Monday, our morning coffee chat with you that is all ab… [+2045 chars] This story originally appeared on MarketBeatWhen meme coins surged earlier this year (remember Dogecoin mania?) it might've been easy to dump everything you owned — stocks, bonds, gold — for crypto. … [+6151 chars] By Reuters Staff
# (Adds context, background)
# June 13 (Reuters) - Bitcoin surged 9.8% to $39,035.47 on Sunday, adding $3,492.71 to its previous close.
# Bitcoin, the worlds biggest and best-known cryp… [+877 chars] A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken March 15, 2021. REUTERS/Dado Ruvic/IllustrationLONDON, June 30 (Reuters) - If you're a bitcoi… [+3630 chars] TOKYO, June 21 (Reuters) - Cryptocurrencies tumbled on Monday as China's crackdown on bitcoin mining expanded to the province of Sichuan. read more
# Bitcoin fell to as low as $32,288 for the first t… [+377 chars] By Reuters Staff
# FILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this picture illustration taken June 7, 2021. REUTERS/Edgar Su/Illustration
# (Reuters) - Bitcoin dropped 5.71% … [+336 chars] Bitcoin dropped 5.71% to $35,210 at 0600 GMT on Saturday, losing $2,131.11 from its previous close.
# Bitcoin, the world's biggest and best-known cryptocurrency, is down 45.7% from its 2021 high of $6… [+215 chars] June 21 (Reuters) - Bitcoin dipped 8.57% to $32,540.35 at 2011 GMT on Monday, losing $3,049.42 from its previous close.
# Bitcoin, the world's biggest and best-known cryptocurrency, is down 49.9% from… [+308 chars] By Reuters Staff
# June 21 (Reuters) - Bitcoin dipped 8.57% to $32,540.35 at 2011 GMT on Monday, losing $3,049.42 from its previous close.
# Bitcoin, the worlds biggest and best-known cryptocurrency, i… [+269 chars] A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/IllustrationJune 25 (Reuters) - Bitcoin dropped 7.37% to $32,094.44 o… [+434 chars] Posted
# Bitcoin tumbled on Monday after news of a fresh crackdown on the cryptocurrency's miners in China. By Reuters Staff
# FILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File Photo
# (Reuters) - Bitcoin ros… [+304 chars] By Reuters Staff
# June 25 (Reuters) - Bitcoin dropped 7.37% to $32,094.44 on Friday, losing $2,554.88 from its previous close.
# Bitcoin, the worlds biggest and best-known cryptocurrency, is down 50.5… [+253 chars]

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
btc_doc = nlp(btc_text_string)
# Add a title to the document
# YOUR CODE HERE!
btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  caused ripples in the cryptocurrency market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  by announcing that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after ransomware attackers started
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the holiday weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The gang behind a &quot;colossal&quot; ransomware attack has demanded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $70m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     £50.5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in return for a &quot;universal decryptor&quot; that it says will unlock the files of all … [+4140 chars] SAN SALVADOR,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will not replace the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar with bitcoin as the legal tender,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alejandro Zelaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  nation so… [+1266 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em

# %%
# List all Entities
# YOUR CODE HERE!
btc_entities = [ent.text for ent in btc_doc.ents if ent.label_ in ['GPE', 'ORG']]
print(btc_entities)
# Out:
# ['Tesla', 'Verge', 'Reuters', 'El Salvador', 'U.S.', 'Finance', 'LONDON', 'Reuters', 'El Salvador', 'LONDON', 'Reuters', 'El Salvador', 'Reuters', 'Reuters', 'El Salvador', 'U.S.', 'Finance', 'Dogecoin', 'Reuters', 'Reuters', 'Reuters', 'Reuters', 'China', 'Sichuan', 'Reuters', 'Bitcoin', 'Reuters', 'GMT', 'Reuters', 'GMT', 'Reuters', 'Reuters', 'GMT', 'Reuters', 'China', 'Reuters', 'Bitcoin', 'Reuters', 'Reuters', 'Reuters']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_text = []
for text in bitcoin_df.text:
    eth_text.append(text)
    
# Convert a list of texts into a single string of texts   
eth_text_string = ' '.join([str(elem) for elem in eth_text])
print(eth_text_string)
# Out:
# It's all about clean energy, it seems.
# Elon Musk and Tesla caused ripples in the cryptocurrency market in the past few months, first by announcing that Tesla had bought $1.5 billion worth of bitcoi… [+2508 chars] Filed under:
# The supply chain attack has reached over a thousand organizations.
# Illustration by Alex Castro / The Verge
# Three days after ransomware attackers started the holiday weekend by comprom… [+3376 chars] image copyrightGetty Images
# The gang behind a "colossal" ransomware attack has demanded $70m (£50.5m) paid in Bitcoin in return for a "universal decryptor" that it says will unlock the files of all … [+4140 chars] SAN SALVADOR, June 16 (Reuters) - El Salvador will not replace the U.S. dollar with bitcoin as the legal tender, Finance Minister Alejandro Zelaya said on Wednesday, as the Central American nation so… [+1266 chars] LONDON, June 23 (Reuters) - El Salvador is determined to push ahead with making bitcoin legal tender, a process that will bring only small risks and prove a leap forward for humanity, the countrys Pr… [+2648 chars] LONDON, June 23 (Reuters) - El Salvador is determined to push ahead with making bitcoin legal tender, a process that will bring only small risks and prove a "leap forward for humanity", the country's… [+2764 chars] By Reuters Staff
# SAN SALVADOR (Reuters) - El Salvador will not replace the U.S. dollar with bitcoin as the legal tender, Finance Minister Alejandro Zelaya said on Wednesday, as the Central American … [+1110 chars] Hello and welcome back to Equity, TechCrunchs venture capital-focused podcast where we unpack the numbers behind the headlines.
# This is Equity Monday, our morning coffee chat with you that is all ab… [+2045 chars] This story originally appeared on MarketBeatWhen meme coins surged earlier this year (remember Dogecoin mania?) it might've been easy to dump everything you owned — stocks, bonds, gold — for crypto. … [+6151 chars] By Reuters Staff
# (Adds context, background)
# June 13 (Reuters) - Bitcoin surged 9.8% to $39,035.47 on Sunday, adding $3,492.71 to its previous close.
# Bitcoin, the worlds biggest and best-known cryp… [+877 chars] A representation of virtual currency Bitcoin is seen in front of a stock graph in this illustration taken March 15, 2021. REUTERS/Dado Ruvic/IllustrationLONDON, June 30 (Reuters) - If you're a bitcoi… [+3630 chars] TOKYO, June 21 (Reuters) - Cryptocurrencies tumbled on Monday as China's crackdown on bitcoin mining expanded to the province of Sichuan. read more
# Bitcoin fell to as low as $32,288 for the first t… [+377 chars] By Reuters Staff
# FILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this picture illustration taken June 7, 2021. REUTERS/Edgar Su/Illustration
# (Reuters) - Bitcoin dropped 5.71% … [+336 chars] Bitcoin dropped 5.71% to $35,210 at 0600 GMT on Saturday, losing $2,131.11 from its previous close.
# Bitcoin, the world's biggest and best-known cryptocurrency, is down 45.7% from its 2021 high of $6… [+215 chars] June 21 (Reuters) - Bitcoin dipped 8.57% to $32,540.35 at 2011 GMT on Monday, losing $3,049.42 from its previous close.
# Bitcoin, the world's biggest and best-known cryptocurrency, is down 49.9% from… [+308 chars] By Reuters Staff
# June 21 (Reuters) - Bitcoin dipped 8.57% to $32,540.35 at 2011 GMT on Monday, losing $3,049.42 from its previous close.
# Bitcoin, the worlds biggest and best-known cryptocurrency, i… [+269 chars] A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/IllustrationJune 25 (Reuters) - Bitcoin dropped 7.37% to $32,094.44 o… [+434 chars] Posted
# Bitcoin tumbled on Monday after news of a fresh crackdown on the cryptocurrency's miners in China. By Reuters Staff
# FILE PHOTO: Representations of the Bitcoin cryptocurrency are seen in this illustration picture taken June 7, 2021. REUTERS/Edgar Su/Illustration/File Photo
# (Reuters) - Bitcoin ros… [+304 chars] By Reuters Staff
# June 25 (Reuters) - Bitcoin dropped 7.37% to $32,094.44 on Friday, losing $2,554.88 from its previous close.
# Bitcoin, the worlds biggest and best-known cryptocurrency, is down 50.5… [+253 chars]

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
eth_doc = nlp(eth_text_string)
# Add a title to the document
# YOUR CODE HERE!
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!

displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  caused ripples in the cryptocurrency market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  by announcing that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alex Castro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Verge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after ransomware attackers started
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the holiday weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The gang behind a &quot;colossal&quot; ransomware attack has demanded
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $70m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     £50.5m
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) paid in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in return for a &quot;universal decryptor&quot; that it says will unlock the files of all … [+4140 chars] SAN SALVADOR,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will not replace the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar with bitcoin as the legal tender,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Finance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alejandro Zelaya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  nation so… [+1266 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LONDON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35e

# %%
# List all Entities
# YOUR CODE HERE!
eth_entities = [ent.text for ent in eth_doc.ents if ent.label_ in ['GPE', 'ORG']]
print(eth_entities)
# Out:
# ['Tesla', 'Verge', 'Reuters', 'El Salvador', 'U.S.', 'Finance', 'LONDON', 'Reuters', 'El Salvador', 'LONDON', 'Reuters', 'El Salvador', 'Reuters', 'Reuters', 'El Salvador', 'U.S.', 'Finance', 'Dogecoin', 'Reuters', 'Reuters', 'Reuters', 'Reuters', 'China', 'Sichuan', 'Reuters', 'Bitcoin', 'Reuters', 'GMT', 'Reuters', 'GMT', 'Reuters', 'Reuters', 'GMT', 'Reuters', 'China', 'Reuters', 'Bitcoin', 'Reuters', 'Reuters', 'Reuters']

# %% [markdown]
# ---
